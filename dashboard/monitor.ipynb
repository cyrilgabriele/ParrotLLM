# %% [markdown]
# # ParrotLLM Training Monitor
#
# Run the cell below to launch the interactive training dashboard.
# Select a run from the dropdown, then use **Start** / **Resume** / **Stop** to control training.

# %%
import sys
from pathlib import Path

# Make sure the project root is on the path when running from dashboard/
project_root = Path().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.dashboard.notebook import monitor

monitor(
    runs_dir=project_root / "runs",
    config_path=project_root / "configs" / "default.yaml",
    refresh=2,
)
# Out:
# /Users/gian1/CODE/HSG/FS26/NLP/ParrotLLM/src/dashboard/plots.py:107: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(pad=1.5)
# ...
